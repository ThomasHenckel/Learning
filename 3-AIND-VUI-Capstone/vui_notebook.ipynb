# %% [markdown]
# <a id='model4'></a>
# ### (IMPLEMENTATION) Model 4: Bidirectional RNN + TimeDistributed Dense
#
# Read about the [Bidirectional](https://keras.io/layers/wrappers/) wrapper in the Keras documentation.  For your next architecture, you will specify an architecture that uses a single bidirectional RNN layer, before a (`TimeDistributed`) dense layer.  The added value of a bidirectional RNN is described well in [this paper](http://www.cs.toronto.edu/~hinton/absps/DRNN_speech.pdf).
# > One shortcoming of conventional RNNs is that they are only able to make use of previous context. In speech recognition, where whole utterances are transcribed at once, there is no reason not to exploit future context as well.  Bidirectional RNNs (BRNNs) do this by processing the data in both directions with two separate hidden layers which are then fed forwards to the same output layer.
#
# <img src="images/bidirectional_rnn_model.png" width="80%">
#
# Before running the code cell below, you must complete the `bidirectional_rnn_model` function in `sample_models.py`.  Feel free to use `SimpleRNN`, `LSTM`, or `GRU` units.  When specifying the `Bidirectional` wrapper, use `merge_mode='concat'`.

# %%
model_4 = bidirectional_rnn_model(input_dim=161, # change to 13 if you would like to use MFCC features
                                  units=200)
# Out:
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# the_input (InputLayer)       (None, None, 161)         0
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, None, 400)         434400
# _________________________________________________________________
# time_distributed_4 (TimeDist (None, None, 29)          11629
# _________________________________________________________________
# softmax (Activation)         (None, None, 29)          0
# =================================================================
# Total params: 446,029
# Trainable params: 446,029
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# Please execute the code cell below to train the neural network you specified in `input_to_softmax`.  After the model has finished training, the model is [saved](https://keras.io/getting-started/faq/#how-can-i-save-a-keras-model) in the HDF5 file `model_4.h5`.  The loss history is [saved](https://wiki.python.org/moin/UsingPickle) in `model_4.pickle`.  You are welcome to tweak any of the optional parameters while calling the `train_model` function, but this is not required.

# %%
train_model(input_to_softmax=model_4, 
            pickle_path='model_4.pickle', 
            save_model_path='model_4.h5', 
            spectrogram=True) # change to False if you would like to use MFCC features
# Out:
# Epoch 1/20
# 101/101 [==============================] - 203s 2s/step - loss: 274.8626 - val_loss: 161.6058
# Epoch 2/20
# 101/101 [==============================] - 208s 2s/step - loss: 213.6204 - val_loss: 218.5463
# Epoch 3/20
# 101/101 [==============================] - 207s 2s/step - loss: 198.3253 - val_loss: 152.7106
# Epoch 4/20
# 101/101 [==============================] - 207s 2s/step - loss: 187.8534 - val_loss: 196.9296
# Epoch 5/20
# 101/101 [==============================] - 211s 2s/step - loss: 179.1387 - val_loss: 160.1888
# Epoch 6/20
# 101/101 [==============================] - 207s 2s/step - loss: 172.2318 - val_loss: 150.9364
# Epoch 7/20
# 101/101 [==============================] - 205s 2s/step - loss: 165.8789 - val_loss: 149.1252
# Epoch 8/20
# 101/101 [==============================] - 209s 2s/step - loss: 160.0380 - val_loss: 153.5021
# Epoch 9/20
# 101/101 [==============================] - 207s 2s/step - loss: 154.8097 - val_loss: 168.1861
# Epoch 10/20
# 101/101 [==============================] - 206s 2s/step - loss: 149.1819 - val_loss: 182.2381
# Epoch 11/20
# 101/101 [==============================] - 208s 2s/step - loss: 144.2081 - val_loss: 162.1089
# Epoch 12/20
# 101/101 [==============================] - 208s 2s/step - loss: 139.5348 - val_loss: 118.2652
# Epoch 13/20
# 101/101 [==============================] - 208s 2s/step - loss: 135.4065 - val_loss: 159.9524
# Epoch 14/20
# 101/101 [==============================] - 211s 2s/step - loss: 131.7379 - val_loss: 132.0924
# Epoch 15/20
# 101/101 [==============================] - 209s 2s/step - loss: 128.0888 - val_loss: 149.4257
# Epoch 16/20
# 101/101 [==============================] - 207s 2s/step - loss: 124.8048 - val_loss: 136.4301
# Epoch 17/20
# 101/101 [==============================] - 208s 2s/step - loss: 121.8667 - val_loss: 124.9375
# Epoch 18/20
# 101/101 [==============================] - 210s 2s/step - loss: 119.1295 - val_loss: 154.6786
# Epoch 19/20
# 101/101 [==============================] - 208s 2s/step - loss: 116.5865 - val_loss: 139.6230
# Epoch 20/20
# 101/101 [==============================] - 209s 2s/step - loss: 114.2581 - val_loss: 106.1249

# %% [markdown]
# <a id='model5'></a>
# ### (OPTIONAL IMPLEMENTATION) Models 5+
#
# If you would like to try out more architectures than the ones above, please use the code cell below.  Please continue to follow the same convention for saving the models; for the $i$-th sample model, please save the loss at **`model_i.pickle`** and saving the trained model at **`model_i.h5`**.

# %%
def cnn_rnn_model(input_dim, filters, kernel_size, conv_stride,
    conv_border_mode, units, output_dim=29):
    """ Build a recurrent + convolutional network for speech 
    """
    # Main acoustic input
    input_data = Input(name='the_input', shape=(None, input_dim))
    # Add convolutional layer
    conv_1d = Conv1D(filters, kernel_size, 
                     strides=conv_stride, 
                     padding=conv_border_mode,
                     activation='relu',
                     name='conv1d'
                    )(input_data)
    # Add batch normalization
    bn_cnn = BatchNormalization(name='bn_conv_1d')(conv_1d)
    # Add a recurrent layer
    simp_rnn = Bidirectional(GRU(units, activation='relu',
        return_sequences=True, implementation=2, name='rnn'))(bn_cnn)
    # TODO: Add batch normalization
    bn_rnn = BatchNormalization()(simp_rnn)
    # TODO: Add a TimeDistributed(Dense(output_dim)) layer
    time_dense = TimeDistributed(Dense(output_dim))(bn_rnn)
    # Add softmax activation layer
    y_pred = Activation('softmax', name='softmax')(time_dense)
    # Specify the model
    model = Model(inputs=input_data, outputs=y_pred)
    model.output_length = lambda x: cnn_output_length(
        x, kernel_size, conv_border_mode, conv_stride)
    print(model.summary())
    return model

# %%
model_5 = cnn_rnn_model(input_dim=161, # change to 13 if you would like to use MFCC features
                        filters=200,
                        kernel_size=11, 
                        conv_stride=2,
                        conv_border_mode='valid',
                        units=200)
# Out:
# Model: "model_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# the_input (InputLayer)       (None, None, 161)         0
# _________________________________________________________________
# conv1d (Conv1D)              (None, None, 200)         354400
# _________________________________________________________________
# bn_conv_1d (BatchNormalizati (None, None, 200)         800
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, None, 400)         481200
# _________________________________________________________________
# batch_normalization_5 (Batch (None, None, 400)         1600
# _________________________________________________________________
# time_distributed_5 (TimeDist (None, None, 29)          11629
# _________________________________________________________________
# softmax (Activation)         (None, None, 29)          0
# =================================================================
# Total params: 849,629
# Trainable params: 848,429
# Non-trainable params: 1,200
# _________________________________________________________________
# None

# %%
train_model(input_to_softmax=model_5, 
            pickle_path='model_5.pickle', 
            save_model_path='model_5.h5', 
            spectrogram=True) # change to False if you would like to use MFCC features
# Out:
# Epoch 1/20
# 101/101 [==============================] - 120s 1s/step - loss: 251.3643 - val_loss: 317.5548
# Epoch 2/20
# 101/101 [==============================] - 121s 1s/step - loss: 193.8156 - val_loss: 132.7180
# Epoch 3/20
# 101/101 [==============================] - 124s 1s/step - loss: 160.9796 - val_loss: 161.2038
# Epoch 4/20
# 101/101 [==============================] - 121s 1s/step - loss: 142.4200 - val_loss: 142.9162
# Epoch 5/20
# 101/101 [==============================] - 121s 1s/step - loss: 130.3587 - val_loss: 159.6140
# Epoch 6/20
# 101/101 [==============================] - 121s 1s/step - loss: 121.1858 - val_loss: 142.2039
# Epoch 7/20
# 101/101 [==============================] - 121s 1s/step - loss: 113.1837 - val_loss: 151.2381
# Epoch 8/20
# 101/101 [==============================] - 121s 1s/step - loss: 106.1990 - val_loss: 136.7944
# Epoch 9/20
# 101/101 [==============================] - 123s 1s/step - loss: 99.5780 - val_loss: 125.2540
# Epoch 10/20
# 101/101 [==============================] - 120s 1s/step - loss: 93.5098 - val_loss: 138.2438
# Epoch 11/20
# 101/101 [==============================] - 122s 1s/step - loss: 88.2189 - val_loss: 106.4898
# Epoch 12/20
# 101/101 [==============================] - 121s 1s/step - loss: 82.7929 - val_loss: 142.8069
# Epoch 13/20
# 101/101 [==============================] - 124s 1s/step - loss: 77.8350 - val_loss: 123.6694
# Epoch 14/20
# 101/101 [==============================] - 122s 1s/step - loss: 72.9208 - val_loss: 118.3021
# Epoch 15/20
# 101/101 [==============================] - 121s 1s/step - loss: 67.9687 - val_loss: 135.4857
# Epoch 16/20
# 101/101 [==============================] - 122s 1s/step - loss: 63.3681 - val_loss: 136.2814
# Epoch 17/20
# 101/101 [==============================] - 123s 1s/step - loss: 58.7283 - val_loss: 155.6527
# Epoch 18/20
# 101/101 [==============================] - 125s 1s/step - loss: 54.4894 - val_loss: 138.7926
# Epoch 19/20
# 101/101 [==============================] - 121s 1s/step - loss: 50.5838 - val_loss: 155.1338
# Epoch 20/20
# 101/101 [==============================] - 122s 1s/step - loss: 46.5747 - val_loss: 179.9059

# %% [markdown]
# <a id='compare'></a>
# ### Compare the Models
#
# Execute the code cell below to evaluate the performance of the drafted deep learning models.  The training and validation loss are plotted for each model.

# %%
from glob import glob
import numpy as np
import _pickle as pickle
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set_style(style='white')

def plotModels(path = "results/"):
    # obtain the paths for the saved model history
    all_pickles = sorted(glob(path + "*.pickle"))
    # extract the name of each model
    model_names = [item[8:-7] for item in all_pickles]
    # extract the loss history for each model
    valid_loss = [pickle.load( open( i, "rb" ) )['val_loss'] for i in all_pickles]
    train_loss = [pickle.load( open( i, "rb" ) )['loss'] for i in all_pickles]
    # save the number of epochs used to train each model
    num_epochs = [len(valid_loss[i]) for i in range(len(valid_loss))]

    fig = plt.figure(figsize=(16,5))

    # plot the training loss vs. epoch for each model
    ax1 = fig.add_subplot(121)
    for i in range(len(all_pickles)):
        ax1.plot(np.linspace(1, num_epochs[i], num_epochs[i]), 
                train_loss[i], label=model_names[i])
    # clean up the plot
    ax1.legend()  
    ax1.set_xlim([1, max(num_epochs)])
    plt.xlabel('Epoch')
    plt.ylabel('Training Loss')

    # plot the validation loss vs. epoch for each model
    ax2 = fig.add_subplot(122)
    for i in range(len(all_pickles)):
        ax2.plot(np.linspace(1, num_epochs[i], num_epochs[i]), 
                valid_loss[i], label=model_names[i])
    # clean up the plot
    ax2.legend()  
    ax2.set_xlim([1, max(num_epochs)])
    plt.xlabel('Epoch')
    plt.ylabel('Validation Loss')
    plt.show()
    
plotModels()

# %% [markdown]
# __Question 1:__ Use the plot above to analyze the performance of each of the attempted architectures.  Which performs best?  Provide an explanation regarding why you think some models perform better than others.
#
# __Answer:__
#
# Model 0 = RNN
# Model 1 = RNN Time distributed
# Model 2 = CNN RNN Time Distributed
# Model 3 = RNN RNN Time Distributed
# Model 4 = Bidirectional(RNN) Time Distributed
# Model 5 = CNN Bidirectional(RNN) Time Distributed
#
# Looking at the model results, it is clear that model 0 stands out, the single RNN looks to have trouble learning from the input. Adding a Time Distribution layer helps greatly, and logically this makes sense as ords an sounds has a pattern and the sound in one times step has a strong relation to the next
#
# To get a better compareson on the rest of the networks, the resoults are plotted without model 0

# %%
import os
# make results/ directory, if necessary
if not os.path.exists('results/initial'):
    os.makedirs('results/initial')

import shutil
shutil.copy2('results/model_1.h5', 'results/initial')
shutil.copy2('results/model_1.pickle', 'results/initial')

shutil.copy2('results/model_2.h5', 'results/initial')
shutil.copy2('results/model_2.pickle', 'results/initial')

shutil.copy2('results/model_3.h5', 'results/initial')
shutil.copy2('results/model_3.pickle', 'results/initial')

shutil.copy2('results/model_4.h5', 'results/initial')
shutil.copy2('results/model_4.pickle', 'results/initial')

shutil.copy2('results/model_5.h5', 'results/initial')
shutil.copy2('results/model_5.pickle', 'results/initial')


plotModels("results/initial/")

# %% [markdown]
# __Answer Continued:__
#
# Model 1 (Blue) = RNN Time distributed
# Model 2 (yellow) = CNN RNN Time Distributed
# Model 3 (green) = RNN RNN Time Distributed
# Model 4 (red) = Bidirectional(RNN) Time Distributed
# Model 5 (pink) = CNN Bidirectional(RNN) Time Distributed
#
# **Model 1 (Blue) = RNN Time distributed**
# Ther are not really any winner, when looking at the 5 networks.
# Adding Time Distributed made a great improvement. This network is the one offering the best final validation loss. however beause of the small data size the validation loss is fluctuating a lot from epoch to epoch.
#
# **Model 2 (yellow) = CNN RNN Time Distributed**
# Adding an CNN gives the network the capability to capture more features, however this network starts to overfit after around the 10. epoch
#
# **Model 3 (green) = RNN RNN Time Distributed**
# Having 2xRNN looks to work much like 1xRNN it is able to get slightly better training loss, but the validation loss looks to me much the same as with 1xRNN. and in such the capacity is higher in the network, but does not capture better features.
#
# **Model 4 (red) = Bidirectional(RNN) Time Distributed**
# Bidirectional RNN sounds like a valid aproach, as speach have specific patterns and the sound both befor and after the timestep should be relevant.
# After 20 epochs the Validation loss has not platoued, and it might be relevant to train this network for a bit longer. the Validation loss is not better than the RNN or 2xRNN
#
# **Model 5 (pink) = CNN Bidirectional(RNN) Time Distributed**
# Combining some of the approches in the specified networks, a test is done taking the CNN and Bidirectional(CNN), this network has the capacity to learn much more from the training signal and is the one to give the lovest Trainaing Loss. Hovever the model is overfitting and is not giving better Validation Loses than the other models.

# %% [markdown]
# <a id='final'></a>
# ### (IMPLEMENTATION) Final Model
#
# Now that you've tried out many sample models, use what you've learned to draft your own architecture!  While your final acoustic model should not be identical to any of the architectures explored above, you are welcome to merely combine the explored layers above into a deeper architecture.  It is **NOT** necessary to include new layer types that were not explored in the notebook.
#
# However, if you would like some ideas for even more layer types, check out these ideas for some additional, optional extensions to your model:
#
# - If you notice your model is overfitting to the training dataset, consider adding **dropout**!  To add dropout to [recurrent layers](https://faroit.github.io/keras-docs/1.0.2/layers/recurrent/), pay special attention to the `dropout_W` and `dropout_U` arguments.  This [paper](http://arxiv.org/abs/1512.05287) may also provide some interesting theoretical background.
# - If you choose to include a convolutional layer in your model, you may get better results by working with **dilated convolutions**.  If you choose to use dilated convolutions, make sure that you are able to accurately calculate the length of the acoustic model's output in the `model.output_length` lambda function.  You can read more about dilated convolutions in Google's [WaveNet paper](https://arxiv.org/abs/1609.03499).  For an example of a speech-to-text system that makes use of dilated convolutions, check out this GitHub [repository](https://github.com/buriburisuri/speech-to-text-wavenet).  You can work with dilated convolutions [in Keras](https://keras.io/layers/convolutional/) by paying special attention to the `padding` argument when you specify a convolutional layer.
# - If your model makes use of convolutional layers, why not also experiment with adding **max pooling**?  Check out [this paper](https://arxiv.org/pdf/1701.02720.pdf) for example architecture that makes use of max pooling in an acoustic model.
# - So far, you have experimented with a single bidirectional RNN layer.  Consider stacking the bidirectional layers, to produce a [deep bidirectional RNN](https://www.cs.toronto.edu/~graves/asru_2013.pdf)!
#
# All models that you specify in this repository should have `output_length` defined as an attribute.  This attribute is a lambda function that maps the (temporal) length of the input acoustic features to the (temporal) length of the output softmax layer.  This function is used in the computation of CTC loss; to see this, look at the `add_ctc_loss` function in `train_utils.py`.  To see where the `output_length` attribute is defined for the models in the code, take a look at the `sample_models.py` file.  You will notice this line of code within most models:
# ```
# model.output_length = lambda x: x
# ```
# The acoustic model that incorporates a convolutional layer (`cnn_rnn_model`) has a line that is a bit different:
# ```
# model.output_length = lambda x: cnn_output_length(
#         x, kernel_size, conv_border_mode, conv_stride)
# ```
#
# In the case of models that use purely recurrent layers, the lambda function is the identity function, as the recurrent layers do not modify the (temporal) length of their input tensors.  However, convolutional layers are more complicated and require a specialized function (`cnn_output_length` in `sample_models.py`) to determine the temporal length of their output.
#
# You will have to add the `output_length` attribute to your final model before running the code cell below.  Feel free to use the `cnn_output_length` function, if it suits your model.

# %% [markdown]
# # Dropout

# %%
dropouts= [0,0.1,0.3,0.5]
import os
# make results/ directory, if necessary
if not os.path.exists('results/dropout'):
    os.makedirs('results/dropout')

for i,dropout in enumerate(dropouts):
    model_end = final_model(input_dim=161, # change to 13 if you would like to use MFCC features
                            filters=200,
                            kernel_size=11, 
                            conv_stride=2,
                            conv_border_mode='valid',
                            units=200,
                            rnn_layers=1,
                            dropout = dropout,
                            recurrent_dropout = 0,
                            dilation_rate=1,
                            pool_size = 1)

    train_model(input_to_softmax=model_end, 
                pickle_path='dropout/model_end_take'+str(i)+'.pickle', 
                save_model_path='dropout/model_end_take'+str(i)+'.h5', 
                spectrogram=True) # change to False if you would like to use MFCC features
# Out:
# Model: "model_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# the_input (InputLayer)       (None, None, 161)         0
# _________________________________________________________________
# conv1d (Conv1D)              (None, None, 200)         354400
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, None, 200)         0
# _________________________________________________________________
# bidirectional_3 (Bidirection (None, None, 400)         481200
# _________________________________________________________________
# batch_normalization_6 (Batch (None, None, 400)         1600
# _________________________________________________________________
# time_distributed_6 (TimeDist (None, None, 29)          11629
# _________________________________________________________________
# softmax (Activation)         (None, None, 29)          0
# =================================================================
# Total params: 848,829
# Trainable params: 848,029
# Non-trainable params: 800
# _________________________________________________________________
# None
# Epoch 1/20
# 101/101 [==============================] -
# Model: "model_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# the_input (InputLayer)       (None, None, 161)         0
# _________________________________________________________________
# conv1d (Conv1D)              (None, None, 200)         354400
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, None, 200)         0
# _________________________________________________________________
# bidirectional_6 (Bidirection (None, None, 400)         481200
# _________________________________________________________________
# batch_normalization_9 (Batch (None, None, 400)         1600
# _________________________________________________________________
# time_distributed_9 (TimeDist (None, None, 29)          11629
# _________________________________________________________________
# softmax (Activation)         (None, None, 29)          0
# =================================================================
# Total params: 848,829
# Trainable params: 848,029
# Non-trainable params: 800
# _________________________________________________________________
# None
# Epoch 1/20
# 101/101 [==============================] - 123s 1s/step - loss: 280.8280 - val_loss: 282.7628
# Epoch 2/20
# 101/101 [==============================] - 125s 1s/step - loss: 218.4032 - val_loss: 188.8171
# Epoch 3/20
# 101/101 [==============================] - 124s 1s/step - loss: 185.8735 - val_loss: 201.3084
# Epoch 4/20
# 101/101 [==============================] - 124s 1s/step - loss: 168.7204 - val_loss: 156.6842
# Epoch 5/20
# 101/101 [==============================] - 125s 1s/step - loss: 158.4277 - val_loss: 157.1016
# Epoch 6/20
# 101/101 [==============================] - 125s 1s/step - loss: 151.1485 - val_loss: 129.5829
# Epoch 7/20
# 101/101 [==============================] - 124s 1s/step - loss: 145.1118 - val_loss: 147.9948
# Epoch 8/20
# 101/101 [==============================] - 125s 1s/step - loss: 140.4793 - val_loss: 117.8703
# Epoch 9/20
# 101/101 [==============================] - 125s 1s/step - loss: 136.3455 - val_loss: 158.8685
# Epoch 10/20
# 101/101 [==============================] - 124s 1s/step - loss: 133.1182 - val_loss: 144.0661
# Epoch 11/20
# 101/101 [==============================] - 129s 1s/step - loss: 130.0301 - val_loss: 120.3096
# Epoch 12/20
# 101/101 [==============================] - 125s 1s/step - loss: 127.9688 - val_loss: 147.5882
# Epoch 13/20
# 101/101 [==============================] - 126s 1s/step - loss: 125.3587 - val_loss: 124.8109
# Epoch 14/20
# 101/101 [==============================] - 125s 1s/step - loss: 123.6988 - val_loss: 113.3403
# Epoch 15/20
# 101/101 [==============================] - 125s 1s/step - loss: 121.6494 - val_loss: 96.8855
# Epoch 16/20
# 101/101 [==============================] - 125s 1s/step - loss: 119.7513 - val_loss: 109.2844
# Epoch 17/20
# 101/101 [==============================] - 124s 1s/step - loss: 118.3897 - val_loss: 119.2632
# Epoch 18/20
# 101/101 [==============================] - 125s 1s/step - loss: 117.3816 - val_loss: 125.1352
# Epoch 19/20
# 101/101 [==============================] - 126s 1s/step - loss: 115.7940 - val_loss: 142.1026
# Epoch 20/20
# 101/101 [==============================] - 124s 1s/step - loss: 114.6437 - val_loss: 112.2200

# %%
plotModels("results/dropout/")

# %% [markdown]
# # Dropout conclussion
#
#
# Take 1 = CNN Bidirectional(RNN(Dropout = 0)) Time Distributed
# Take 2 = CNN Bidirectional(RNN(Dropout = 0.1)) Time Distributed
# Take 3 = CNN Bidirectional(RNN(Dropout = 0.3)) Time Distributed
#
# Dropout is handling a lot of the overfitting, looks like a dropoutrate around 0.3 to 0.5 works well
# The remaining experiments will be done with 0.3 dropout rate

# %% [markdown]
# # Dilated convolutions

# %%
dis= [2,4,8]

# make results/ directory, if necessary
if not os.path.exists('results/di'):
    os.makedirs('results/di')
    
import shutil
shutil.copy2('results/dropout/model_end_take2.h5', 'results/di')
shutil.copy2('results/dropout/model_end_take2.pickle', 'results/di')

for i,di in enumerate(dis):
    model_end = final_model(input_dim=161, # change to 13 if you would like to use MFCC features
                            filters=200,
                            kernel_size=11, 
                            conv_stride=1,
                            conv_border_mode='valid',
                            units=200,
                            rnn_layers=1,
                            dropout = 0.3,
                            recurrent_dropout = 0,
                            dilation_rate=di,
                            pool_size = 1)

    train_model(input_to_softmax=model_end, 
                pickle_path='di/model_end_rnn_take'+str(i)+'.pickle', 
                save_model_path='di/model_end_rnn_take'+str(i)+'.h5', 
                spectrogram=True) # change to False if you would like to use MFCC features
# Out:
# Model: "model_21"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# the_input (InputLayer)       (None, None, 161)         0
# _________________________________________________________________
# conv1d (Conv1D)              (None, None, 200)         354400
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, None, 200)         0
# _________________________________________________________________
# bidirectional_7 (Bidirection (None, None, 400)         481200
# _________________________________________________________________
# batch_normalization_10 (Batc (None, None, 400)         1600
# _________________________________________________________________
# time_distributed_10 (TimeDis (None, None, 29)          11629
# _________________________________________________________________
# softmax (Activation)         (None, None, 29)          0
# =================================================================
# Total params: 848,829
# Trainable params: 848,029
# Non-trainable params: 800
# _________________________________________________________________
# None
# Epoch 1/20
# 101/101 [==============================] -
# 101/101 [==============================] - 245s 2s/step - loss: 149.4794 - val_loss: 139.0610
# Epoch 14/20
# 101/101 [==============================] - 243s 2s/step - loss: 148.0186 - val_loss: 128.2187
# Epoch 15/20
# 101/101 [==============================] - 247s 2s/step - loss: 146.7081 - val_loss: 150.4493
# Epoch 16/20
# 101/101 [==============================] - 247s 2s/step - loss: 144.6563 - val_loss: 144.5591
# Epoch 17/20
# 101/101 [==============================] - 248s 2s/step - loss: 144.5536 - val_loss: 156.0809
# Epoch 18/20
# 101/101 [==============================] - 247s 2s/step - loss: 143.6887 - val_loss: 150.7219
# Epoch 19/20
# 101/101 [==============================] - 251s 2s/step - loss: 141.0723 - val_loss: 137.8914
# Epoch 20/20
# 101/101 [==============================] - 248s 2s/step - loss: 140.9339 - val_loss: 133.7431
# Model: "model_25"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# the_input (InputLayer)       (None, None, 161)         0
# _________________________________________________________________
# conv1d (Conv1D)              (None, None, 200)         354400
# _________________________________________________________________
# max_pooling1d_7 (MaxPooling1 (None, None, 200)         0
# _________________________________________________________________
# bidirectional_9 (Bidirection (None, None, 400)         481200
# _________________________________________________________________
# batch_normalization_12 (Batc (None, None, 400)         1600
# _________________________________________________________________
# time_distributed_12 (TimeDis (None, None, 29)          11629
# _________________________________________________________________
# softmax (Activation)         (None, None, 29)          0
# =================================================================
# Total params: 848,829
# Trainable params: 848,029
# Non-trainable params: 800
# _________________________________________________________________
# None
# Epoch 1/20
# 101/101 [==============================] - 235s 2s/step - loss: 282.4777 - val_loss: 171.9134
# Epoch 2/20
# 101/101 [==============================] - 232s 2s/step - loss: 228.0949 - val_loss: 202.6171
# Epoch 3/20
# 101/101 [==============================] - 236s 2s/step - loss: 220.7537 - val_loss: 225.0057
# Epoch 4/20
# 101/101 [==============================] - 232s 2s/step - loss: 217.2003 - val_loss: 196.0396
# Epoch 5/20
# 101/101 [==============================] - 230s 2s/step - loss: nan - val_loss: nan
# Epoch 6/20
# 101/101 [==============================] - 228s 2s/step - loss: nan - val_loss: nan
# Epoch 7/20
# 101/101 [==============================] - 232s 2s/step - loss: nan - val_loss: nan
# Epoch 8/20
# 101/101 [==============================] - 228s 2s/step - loss: nan - val_loss: nan
# Epoch 9/20
# 101/101 [==============================] - 230s 2s/step - loss: nan - val_loss: nan
# Epoch 10/20
# 101/101 [==============================] - 230s 2s/step - loss: nan - val_loss: nan
# Epoch 11/20
# 101/101 [==============================] - 230s 2s/step - loss: nan - val_loss: nan
# Epoch 12/20
# 101/101 [==============================] - 231s 2s/step - loss: nan - val_loss: nan
# Epoch 13/20
# 101/101 [==============================] - 227s 2s/step - loss: nan - val_loss: nan
# Epoch 14/20
# 101/101 [==============================] - 228s 2s/step - loss: nan - val_loss: nan
# Epoch 15/20
# 101/101 [==============================] - 234s 2s/step - loss: nan - val_loss: nan
# Epoch 16/20
# 101/101 [==============================] - 228s 2s/step - loss: nan - val_loss: nan
# Epoch 17/20
# 101/101 [==============================] - 226s 2s/step - loss: nan - val_loss: nan
# Epoch 18/20
# 101/101 [==============================] - 229s 2s/step - loss: nan - val_loss: nan
# Epoch 19/20
# 101/101 [==============================] - 227s 2s/step - loss: nan - val_loss: nan
# Epoch 20/20
# 101/101 [==============================] - 229s 2s/step - loss: nan - val_loss: nan

# %%
plotModels("results/di/")

# %% [markdown]
# # dilated convolutions Conclussion
#
#
# Take_di 1 = CNN(dilation_rate=**2**,conv_stride = 1) Bidirectional(RNN(Dropout = 0.3)) Time Distributed
# Take_di 2 = CNN(dilation_rate=**4**,conv_stride = 1) Bidirectional(RNN(Dropout = 0.3)) Time Distributed
# Take_di 3 = CNN(dilation_rate=**8**,conv_stride = 1) Bidirectional(RNN(Dropout = 0.3)) Time Distributed
# Take 3 = CNN(dilation_rate=**1**,conv_stride = **2**) Bidirectional(RNN(Dropout = 0.3)) Time Distributed
#
# When using dilated convolutions we can not use convolutional strides.
# the experiments show that with this network on this dataset strides performes better that dilated convolutions

# %% [markdown]
# # Max polling

# %%
pool_sizes= [2,4]

# make results/ directory, if necessary
if not os.path.exists('results/maxpoll'):
    os.makedirs('results/maxpoll')
    
import shutil
shutil.copy2('results/dropout/model_end_take2.h5', 'results/maxpoll')
shutil.copy2('results/dropout/model_end_take2.pickle', 'results/maxpoll')

for i,pool_size in enumerate(pool_sizes):
    model_end = final_model(input_dim=161, # change to 13 if you would like to use MFCC features
                            filters=200,
                            kernel_size=11, 
                            conv_stride=1,
                            conv_border_mode='valid',
                            units=200,
                            rnn_layers=1,
                            dropout = 0.3,
                            recurrent_dropout = 0,
                            dilation_rate=1,
                            pool_size = pool_size)

    train_model(input_to_softmax=model_end, 
                pickle_path='maxpoll/model_end_rnn_take'+str(i)+'.pickle', 
                save_model_path='maxpoll/model_end_rnn_take'+str(i)+'.h5', 
                spectrogram=True) # change to False if you would like to use MFCC features
# Out:
# Model: "model_31"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# the_input (InputLayer)       (None, None, 161)         0
# _________________________________________________________________
# conv1d (Conv1D)              (None, None, 200)         354400
# _________________________________________________________________
# max_pooling1d_10 (MaxPooling (None, None, 200)         0
# _________________________________________________________________
# bidirectional_12 (Bidirectio (None, None, 400)         481200
# _________________________________________________________________
# batch_normalization_15 (Batc (None, None, 400)         1600
# _________________________________________________________________
# time_distributed_15 (TimeDis (None, None, 29)          11629
# _________________________________________________________________
# softmax (Activation)         (None, None, 29)          0
# =================================================================
# Total params: 848,829
# Trainable params: 848,029
# Non-trainable params: 800
# _________________________________________________________________
# None
# Epoch 1/20
# 101/101 [==============================] - 138s 1s/step - loss: 254.6884 - val_loss: 193.3646
# Epoch 2/20
# 101/101 [==============================] - 152s 2s/step - loss: 209.5274 - val_loss: 191.0009
# Epoch 3/20
# 101/101 [==============================] - 130s 1s/step - loss: 176.3219 - val_loss: 159.4803
# Epoch 4/20
# 101/101 [==============================] - 132s 1s/step - loss: 157.8807 - val_loss: 132.3165
# Epoch 5/20
# 101/101 [==============================] - 134s 1s/step - loss: 146.4625 - val_loss: 125.4831
# Epoch 6/20
# 101/101 [==============================] - 131s 1s/step - loss: 137.9247 - val_loss: 115.8704
# Epoch 7/20
# 101/101 [==============================] - 127s 1s/step - loss: 131.8341 - val_loss: 109.7141
# Epoch 8/20
# 101/101 [==============================] - 129s 1s/step - loss: 126.9709 - val_loss: 136.4742
# Epoch 9/20
# 101/101 [==============================] - 131s 1s/step - loss: 122.5129 - val_loss: 136.0496
# Epoch 10/20
# 101/101 [==============================] - 129s 1s/step - loss: 119.0344 - val_loss: 111.9338
# Epoch 11/20
# 101/101 [==============================] - 129s 1s/step - loss: 116.1421 - val_loss: 135.7414
# Epoch 12/20
# 101/101 [==============================] - 128s 1s/step - loss: 112.8793 - val_loss: 138.5980
# Epoch 13/20
# 101/101 [==============================] - 127s 1s/step - loss: 109.7929 - val_loss: 114.9956
# Epoch 14/20
# 101/101 [==============================] - 129s 1s/step - loss: 107.9631 - val_loss: 127.3272
# Epoch 15/20
# 101/101 [==============================] - 128s 1s/step - loss: 105.3905 - val_loss: 116.1764
# Epoch 16/20
# 101/101 [==============================] - 128s 1s/step - loss: 103.3244 - val_loss: 111.6770
# Epoch 17/20
# 101/101 [==============================] - 128s 1s/step - loss: 101.4173 - val_loss: 141.8125
# Epoch 18/20
# 101/101 [==============================] - 127s 1s/step - loss: 99.3809 - val_loss: 103.6862
# Epoch 19/20
# 101/101 [==============================] - 128s 1s/step - loss: 98.3291 - val_loss: 115.1746
# Epoch 20/20
# 101/101 [==============================] - 127s 1s/step - loss: 96.0447 - val_loss: 109.1683
# Model: "model_33"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# the_input (InputLayer)       (None, None, 161)         0
# _________________________________________________________________
# conv1d (Conv1D)              (None, None, 200)         354400
# _________________________________________________________________
# max_pooling1d_11 (MaxPooling (None, None, 200)         0
# _________________________________________________________________
# bidirectional_13 (Bidirectio (None, None, 400)         481200
# _________________________________________________________________
# batch_normalization_16 (Batc (None, None, 400)         1600
# _________________________________________________________________
# time_distributed_16 (TimeDis (None, None, 29)          11629
# _________________________________________________________________
# softmax (Activation)         (None, None, 29)          0
# =================================================================
# Total params: 848,829
# Trainable params: 848,029
# Non-trainable params: 800
# _________________________________________________________________
# None
# Epoch 1/20
# 101/101 [==============================] - 68s 676ms/step - loss: 234.6809 - val_loss: 193.2596
# Epoch 2/20
# 101/101 [==============================] - 69s 680ms/step - loss: 197.3588 - val_loss: 160.1507
# Epoch 3/20
# 101/101 [==============================] - 68s 674ms/step - loss: 183.0035 - val_loss: 153.0525
# Epoch 4/20
# 101/101 [==============================] - 68s 678ms/step - loss: 174.5387 - val_loss: 173.0901
# Epoch 5/20
# 101/101 [==============================] - 70s 695ms/step - loss: 168.1591 - val_loss: 154.3319
# Epoch 6/20
# 101/101 [==============================] - 70s 696ms/step - loss: 162.7382 - val_loss: 150.5769
# Epoch 7/20
# 101/101 [==============================] - 68s 676ms/step - loss: 158.4797 - val_loss: 139.6378
# Epoch 8/20
# 101/101 [==============================] - 69s 679ms/step - loss: 154.5601 - val_loss: 152.9367
# Epoch 9/20
# 101/101 [==============================] - 68s 675ms/step - loss: 150.8943 - val_loss: 145.0830
# Epoch 10/20
# 101/101 [==============================] - 69s 684ms/step - loss: 147.5401 - val_loss: 137.8423
# Epoch 11/20
# 101/101 [==============================] - 68s 677ms/step - loss: 144.3762 - val_loss: 154.1504
# Epoch 12/20
# 101/101 [==============================] - 68s 675ms/step - loss: 141.5622 - val_loss: 143.4197
# Epoch 13/20
# 101/101 [==============================] - 68s 675ms/step - loss: 138.9103 - val_loss: 122.7280
# Epoch 14/20
# 101/101 [==============================] - 68s 677ms/step - loss: 136.4261 - val_loss: 133.6870
# Epoch 15/20
# 101/101 [==============================] - 68s 678ms/step - loss: 133.9857 - val_loss: 117.5035
# Epoch 16/20
# 101/101 [==============================] - 68s 673ms/step - loss: 131.2822 - val_loss: 139.3185
# Epoch 17/20
# 101/101 [==============================] - 68s 677ms/step - loss: 129.8250 - val_loss: 152.2868
# Epoch 18/20
# 101/101 [==============================] - 69s 685ms/step - loss: 127.4683 - val_loss: 157.6006
# Epoch 19/20
# 101/101 [==============================] - 69s 680ms/step - loss: 125.7535 - val_loss: 118.8991
# Epoch 20/20
# 101/101 [==============================] - 69s 681ms/step - loss: 123.1908 - val_loss: 136.8095

# %%
plotModels("results/maxpoll/")

# %% [markdown]
# # max polling conclussion
# Take_maxpoll 1 = CNN MaxPolling1D(poll_size = 2) Bidirectional(RNN(Dropout = 0.3)) Time Distributed
# Take_maxpoll 2 = CNN MaxPolling1D(poll_size = 4) Bidirectional(RNN(Dropout = 0.3)) Time Distributed
# Take 3 = CNN Bidirectional(RNN(Dropout = 0.3)) Time Distributed
#
# MaxPolling is redusing the input dimension for the RNN, Looking at the results it looks like it removes to much information, but it also might be that training for a longer time the validation loss when using MaxPoling might get better.

# %% [markdown]
# # Stacked RNN

# %%
rnn= [1,2,3]

# make results/ directory, if necessary
if not os.path.exists('results/stackrnn'):
    os.makedirs('results/stackrnn')
    
import shutil
shutil.copy2('results/dropout/model_end_take2.h5', 'results/stackrnn')
shutil.copy2('results/dropout/model_end_take2.pickle', 'results/stackrnn')

for i in rnn:
    model_end = final_model(input_dim=161, # change to 13 if you would like to use MFCC features
                            filters=200,
                            kernel_size=11, 
                            conv_stride=2,
                            conv_border_mode='valid',
                            units=200,
                            rnn_layers=i,
                            dropout = 0.3,
                            recurrent_dropout = 0,
                            dilation_rate=1,
                            pool_size = 1)

    train_model(input_to_softmax=model_end, 
                pickle_path='stackrnn/model_end_rnn_take'+str(i)+'.pickle', 
                save_model_path='stackrnn/model_end_rnn_take'+str(i)+'.h5', 
                spectrogram=True) # change to False if you would like to use MFCC features
# Out:
# Model: "model_35"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# the_input (InputLayer)       (None, None, 161)         0
# _________________________________________________________________
# conv1d (Conv1D)              (None, None, 200)         354400
# _________________________________________________________________
# max_pooling1d_12 (MaxPooling (None, None, 200)         0
# _________________________________________________________________
# bidirectional_14 (Bidirectio (None, None, 400)         481200
# _________________________________________________________________
# batch_normalization_17 (Batc (None, None, 400)         1600
# _________________________________________________________________
# time_distributed_17 (TimeDis (None, None, 29)          11629
# _________________________________________________________________
# softmax (Activation)         (None, None, 29)          0
# =================================================================
# Total params: 848,829
# Trainable params: 848,029
# Non-trainable params: 800
# _________________________________________________________________
# None
# Epoch 1/20
# 101/101 [==============================] - 124s 1s/step - loss: 274.3324 - val_loss: 167.9928
# Epoch 2/20
# 101/101 [==============================] - 127s 1s/step - loss: 193.2742 - val_loss: 188.4933
# Epoch 3/20
# 101/101 [==============================] - 124s 1s/step - loss: 165.8935 - val_loss: 146.2292
# Epoch 4/20
# 101/101 [==============================] - 126s 1s/step - loss: 151.7558 - val_loss: 151.1825
# Epoch 5/20
# Epoch 15/20
# 101/101 [==============================] - 238s 2s/step - loss: 107.5911 - val_loss: 115.3722
# Epoch 16/20
# 101/101 [==============================] - 241s 2s/step - loss: 105.7204 - val_loss: 107.3753
# Epoch 17/20
# 101/101 [==============================] - 238s 2s/step - loss: 103.6511 - val_loss: 121.9598
# Epoch 18/20
# 101/101 [==============================] - 237s 2s/step - loss: 101.8685 - val_loss: 109.1662
# Epoch 19/20
# 101/101 [==============================] - 237s 2s/step - loss: 99.9852 - val_loss: 132.3380
# Epoch 20/20
# 101/101 [==============================] - 240s 2s/step - loss: 98.5039 - val_loss: 101.2030
# Model: "model_39"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# the_input (InputLayer)       (None, None, 161)         0
# _________________________________________________________________
# conv1d (Conv1D)              (None, None, 200)         354400
# _________________________________________________________________
# max_pooling1d_14 (MaxPooling (None, None, 200)         0
# _________________________________________________________________
# bidirectional_17 (Bidirectio (None, None, 400)         481200
# _________________________________________________________________
# bidirectional_18 (Bidirectio (None, None, 400)         721200
# _________________________________________________________________
# bidirectional_19 (Bidirectio (None, None, 400)         721200
# _________________________________________________________________
# batch_normalization_22 (Batc (None, None, 400)         1600
# _________________________________________________________________
# time_distributed_19 (TimeDis (None, None, 29)          11629
# _________________________________________________________________
# softmax (Activation)         (None, None, 29)          0
# =================================================================
# Total params: 2,291,229
# Trainable params: 2,290,429
# Non-trainable params: 800
# _________________________________________________________________
# None
# Epoch 1/20
# 101/101 [==============================] - 345s 3s/step - loss: 274.8190 - val_loss: 196.9897
# Epoch 2/20
# 101/101 [==============================] - 354s 4s/step - loss: 221.4714 - val_loss: 204.5512
# Epoch 3/20
# 101/101 [==============================] - 354s 4s/step - loss: 197.3131 - val_loss: 168.6889
# Epoch 4/20
# 101/101 [==============================] - 350s 3s/step - loss: 178.6917 - val_loss: 175.0338
# Epoch 5/20
# 101/101 [==============================] - 353s 3s/step - loss: 165.8268 - val_loss: 157.2914
# Epoch 6/20
# 101/101 [==============================] - 359s 4s/step - loss: 156.5880 - val_loss: 146.7672
# Epoch 7/20
# 101/101 [==============================] - 368s 4s/step - loss: 149.4653 - val_loss: 111.3683
# Epoch 8/20
# 101/101 [==============================] - 350s 3s/step - loss: 143.1354 - val_loss: 114.9889
# Epoch 9/20
# 101/101 [==============================] - 356s 4s/step - loss: 138.2763 - val_loss: 137.4800
# Epoch 10/20
# 101/101 [==============================] - 351s 3s/step - loss: 133.4719 - val_loss: 139.2503
# Epoch 11/20
# 101/101 [==============================] - 353s 3s/step - loss: 129.6880 - val_loss: 111.4868
# Epoch 12/20
# 101/101 [==============================] - 355s 4s/step - loss: 126.2950 - val_loss: 108.4182
# Epoch 13/20
# 101/101 [==============================] - 355s 4s/step - loss: 122.9394 - val_loss: 134.2631
# Epoch 14/20
# 101/101 [==============================] - 357s 4s/step - loss: 120.6924 - val_loss: 106.8368
# Epoch 15/20
# 101/101 [==============================] - 350s 3s/step - loss: 117.7786 - val_loss: 121.6630
# Epoch 16/20
# 101/101 [==============================] - 352s 3s/step - loss: 115.4680 - val_loss: 115.5751
# Epoch 17/20
# 101/101 [==============================] - 354s 4s/step - loss: 112.6745 - val_loss: 107.0332
# Epoch 18/20
# 101/101 [==============================] - 355s 4s/step - loss: 110.7080 - val_loss: 104.6176
# Epoch 19/20
# 101/101 [==============================] - 354s 4s/step - loss: 108.9061 - val_loss: 104.5766
# Epoch 20/20
# 101/101 [==============================] - 351s 3s/step - loss: 107.0336 - val_loss: 94.7307

# %%
plotModels("results/stackrnn/")

# %% [markdown]
# # Stacked RNN Conclussion
# Adding more RNN layers is not showing any big diferences, but it looks like the larger networks take longer to train.
#
# After 20 epochs the Trining loss is higher on the networks with more RNN layers, but the validation loss the same on all 3 networks after 20 epochs.
#
# Using more RNN layers and training for longer time coul be a good approach

# %% [markdown]
# # Final Model

# %%
if not os.path.exists('results/final'):
    os.makedirs('results/final')
    
model_end = final_model(input_dim=161, # change to 13 if you would like to use MFCC features
                            filters=200,
                            kernel_size=11, 
                            conv_stride=2,
                            conv_border_mode='valid',
                            units=200,
                            rnn_layers=3,
                            dropout = 0.3,
                            recurrent_dropout = 0,
                            dilation_rate=1,
                            pool_size = 1)

train_model(input_to_softmax=model_end, 
                pickle_path='final/model_end.pickle', 
                save_model_path='final/model_end.h5', 
                epochs=50,
                spectrogram=True) # change to False if you would like to use MFCC features
    
shutil.copy2('results/final/model_end.h5', 'results')
shutil.copy2('results/final/model_end.pickle', 'results')
# Out:
# Model: "model_45"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# the_input (InputLayer)       (None, None, 161)         0
# _________________________________________________________________
# conv1d (Conv1D)              (None, None, 200)         354400
# _________________________________________________________________
# max_pooling1d_17 (MaxPooling (None, None, 200)         0
# _________________________________________________________________
# bidirectional_24 (Bidirectio (None, None, 400)         481200
# _________________________________________________________________
# bidirectional_25 (Bidirectio (None, None, 400)         721200
# _________________________________________________________________
# bidirectional_26 (Bidirectio (None, None, 400)         721200
# _________________________________________________________________
# batch_normalization_29 (Batc (None, None, 400)         1600
# _________________________________________________________________
# time_distributed_22 (TimeDis (None, None, 29)          11629
# _________________________________________________________________
# softmax (Activation)         (None, None, 29)          0
# =================================================================
# Total params: 2,291,229
# Trainable params: 2,290,429
# Non-trainable params: 800
# _________________________________________________________________
# None
# Epoch 1/50
# 101/101 [==============================] - 357s 4s/step - loss: 264.0294 - val_loss: 225.0554
# Epoch 2/50
# 101/101 [==============================] - 358s 4s/step - loss: 223.6316 - val_loss: 213.7536
# Epoch 3/50
# 101/101 [==============================] - 363s 4s/step - loss: 195.1682 - val_loss: 175.4350
# Epoch 4/50
# 101/101 [==============================] - 357s 4s/step - loss: 175.2153 - val_loss: 182.0390
# Epoch 5/50
# 101/101 [==============================] - 359s 4s/step - loss: 163.4855 - val_loss: 164.3206
# Epoch 6/50
# 101/101 [==============================] - 355s 4s/step - loss: 154.5358 - val_loss: 139.5880
# Epoch 7/50
# 101/101 [==============================] - 356s 4s/step - loss: 147.5052 - val_loss: 158.2975
# Epoch 8/50
# 101/101 [==============================] - 360s 4s/step - loss: 141.6175 - val_loss: 132.3941
# Epoch 9/50
# 101/101 [==============================] - 353s 3s/step - loss: 137.8441 - val_loss: 132.4017
# Epoch 10/50
# 101/101 [==============================] - 358s 4s/step - loss: 133.6239 - val_loss: 142.6322
# Epoch 11/50
# 101/101 [==============================] - 359s 4s/step - loss: 130.0815 - val_loss: 129.9149
# Epoch 12/50
# 101/101 [==============================] - 354s 4s/step - loss: 127.0959 - val_loss: 116.7745
# Epoch 13/50
# 101/101 [==============================] - 362s 4s/step - loss: 124.1560 - val_loss: 107.4431
# Epoch 14/50
# 101/101 [==============================] - 357s 4s/step - loss: 122.0140 - val_loss: 125.5768
# Epoch 15/50
# 101/101 [==============================] - 354s 4s/step - loss: 119.5569 - val_loss: 106.6557
# Epoch 16/50
# 101/101 [==============================] - 362s 4s/step - loss: 117.0082 - val_loss: 84.4561
# Epoch 17/50
# 101/101 [==============================] - 359s 4s/step - loss: 114.6879 - val_loss: 106.9408
# Epoch 18/50
# 101/101 [==============================] - 371s 4s/step - loss: 113.3757 - val_loss: 106.8813
# Epoch 19/50
# 101/101 [==============================] - 358s 4s/step - loss: 110.4086 - val_loss: 115.4812
# Epoch 20/50
# 101/101 [==============================] - 355s 4s/step - loss: 108.6203 - val_loss: 104.1008
# Epoch 21/50
# 101/101 [==============================] - 357s 4s/step - loss: 106.6488 - val_loss: 109.1140
# Epoch 22/50
# 101/101 [==============================] - 358s 4s/step - loss: 106.1677 - val_loss: 104.2265
# Epoch 23/50
# 101/101 [==============================] - 362s 4s/step - loss: 103.3943 - val_loss: 106.4087
# Epoch 24/50
# 101/101 [==============================] - 358s 4s/step - loss: 101.8289 - val_loss: 103.3575
# Epoch 25/50
# 101/101 [==============================] - 361s 4s/step - loss: 100.4686 - val_loss: 87.8684
# Epoch 26/50
# 101/101 [==============================] - 362s 4s/step - loss: 99.8162 - val_loss: 111.3802
# Epoch 27/50
# 101/101 [==============================] - 358s 4s/step - loss: 98.3403 - val_loss: 109.7343
# Epoch 28/50
# 101/101 [==============================] - 365s 4s/step - loss: 96.6889 - val_loss: 135.0146
# Epoch 29/50
# 101/101 [==============================] - 359s 4s/step - loss: 96.3092 - val_loss: 99.0020
# Epoch 30/50
# 101/101 [==============================] - 361s 4s/step - loss: 95.0817 - val_loss: 102.2197
# Epoch 31/50
# 101/101 [==============================] - 357s 4s/step - loss: 93.8185 - val_loss: 110.2016
# Epoch 32/50
# 101/101 [==============================] - 359s 4s/step - loss: 92.6381 - val_loss: 94.0219
# Epoch 33/50
# 101/101 [==============================] - 363s 4s/step - loss: 91.7389 - val_loss: 99.8343
# Epoch 34/50
# 101/101 [==============================] - 357s 4s/step - loss: 90.3581 - val_loss: 93.5715
# Epoch 35/50
# 101/101 [==============================] - 359s 4s/step - loss: 89.6780 - val_loss: 95.8391
# Epoch 36/50
# 101/101 [==============================] - 357s 4s/step - loss: 88.1571 - val_loss: 101.0832
# Epoch 37/50
# 101/101 [==============================] - 358s 4s/step - loss: 87.2486 - val_loss: 116.7537
# Epoch 38/50
# 101/101 [==============================] - 357s 4s/step - loss: 86.3404 - val_loss: 112.2782
# Epoch 39/50
# 101/101 [==============================] - 356s 4s/step - loss: 85.7220 - val_loss: 79.9795
# Epoch 40/50
# 101/101 [==============================] - 357s 4s/step - loss: 84.4591 - val_loss: 100.5698
# Epoch 41/50
# 101/101 [==============================] - 357s 4s/step - loss: 84.1409 - val_loss: 81.8618
# Epoch 42/50
# 101/101 [==============================] - 356s 4s/step - loss: 82.1203 - val_loss: 111.2458
# Epoch 43/50
# 101/101 [==============================] - 362s 4s/step - loss: 82.2681 - val_loss: 76.6425
# Epoch 44/50
# 101/101 [==============================] - 357s 4s/step - loss: 82.0982 - val_loss: 100.7809
# Epoch 45/50
# 101/101 [==============================] - 355s 4s/step - loss: 80.5059 - val_loss: 96.2958
# Epoch 46/50
# 101/101 [==============================] - 358s 4s/step - loss: 79.5459 - val_loss: 102.8192
# Epoch 47/50
# 101/101 [==============================] - 359s 4s/step - loss: 79.5977 - val_loss: 99.0494
# Epoch 48/50
# 101/101 [==============================] - 359s 4s/step - loss: 78.8007 - val_loss: 97.8930
# Epoch 49/50
# 101/101 [==============================] - 355s 4s/step - loss: 78.1781 - val_loss: 106.3844
# Epoch 50/50
# 101/101 [==============================] - 356s 4s/step - loss: 77.2182 - val_loss: 109.2631
# 'results\\model_end.pickle'

# %%
    model_end = final_model(input_dim=161, # change to 13 if you would like to use MFCC features
                            filters=200,
                            kernel_size=11, 
                            conv_stride=2,
                            conv_border_mode='valid',
                            units=200,
                            rnn_layers=1,
                            dropout = 0.3,
                            recurrent_dropout = 0,
                            dilation_rate=1,
                            pool_size = 1)

    train_model(input_to_softmax=model_end, 
                pickle_path='final/model_end_dropout_03_0.pickle', 
                save_model_path='final/model_end_dropout_03_0.h5', 
                epochs=50,
                spectrogram=True) # change to False if you would like to use MFCC features
# Out:
# Model: "model_47"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# the_input (InputLayer)       (None, None, 161)         0
# _________________________________________________________________
# conv1d (Conv1D)              (None, None, 200)         354400
# _________________________________________________________________
# max_pooling1d_18 (MaxPooling (None, None, 200)         0
# _________________________________________________________________
# bidirectional_27 (Bidirectio (None, None, 400)         481200
# _________________________________________________________________
# batch_normalization_30 (Batc (None, None, 400)         1600
# _________________________________________________________________
# time_distributed_23 (TimeDis (None, None, 29)          11629
# _________________________________________________________________
# softmax (Activation)         (None, None, 29)          0
# =================================================================
# Total params: 848,829
# Trainable params: 848,029
# Non-trainable params: 800
# _________________________________________________________________
# None
# Epoch 1/50
# 101/101 [==============================] - 124s 1s/step - loss: 256.5577 - val_loss: 183.9461
# Epoch 2/50
# 101/101 [==============================] - 126s 1s/step - loss: 212.0445 - val_loss: 181.9382
# Epoch 3/50
# 101/101 [==============================] - 127s 1s/step - loss: 177.6439 - val_loss: 155.8476
# Epoch 4/50
# 101/101 [==============================] - 126s 1s/step - loss: 159.3292 - val_loss: 152.9409
# Epoch 5/50
# 101/101 [==============================] - 127s 1s/step - loss: 147.5156 - val_loss: 127.3389
# Epoch 6/50
# 101/101 [==============================] - 126s 1s/step - loss: 139.3059 - val_loss: 149.9510
# Epoch 7/50
# 101/101 [==============================] - 126s 1s/step - loss: 132.6355 - val_loss: 117.2488
# Epoch 8/50
# 101/101 [==============================] - 131s 1s/step - loss: 127.4598 - val_loss: 119.2565
# Epoch 9/50
# 101/101 [==============================] - 129s 1s/step - loss: 123.0816 - val_loss: 138.3647
# Epoch 10/50
# 101/101 [==============================] - 128s 1s/step - loss: 119.3878 - val_loss: 108.5424
# Epoch 11/50
# 101/101 [==============================] - 128s 1s/step - loss: 115.5847 - val_loss: 122.4412
# Epoch 12/50
# 101/101 [==============================] - 127s 1s/step - loss: 112.9574 - val_loss: 144.0746
# Epoch 13/50
# 101/101 [==============================] - 127s 1s/step - loss: 110.1734 - val_loss: 114.2872
# Epoch 14/50
# 101/101 [==============================] - 127s 1s/step - loss: 107.4035 - val_loss: 143.5846
# Epoch 15/50
# 101/101 [==============================] - 128s 1s/step - loss: 105.2614 - val_loss: 108.5762
# Epoch 16/50
# 101/101 [==============================] - 127s 1s/step - loss: 103.0227 - val_loss: 97.4624
# Epoch 17/50
# 101/101 [==============================] - 127s 1s/step - loss: 100.8768 - val_loss: 101.4958
# Epoch 18/50
# 101/101 [==============================] - 127s 1s/step - loss: 98.8718 - val_loss: 105.5372
# Epoch 19/50
# 101/101 [==============================] - 126s 1s/step - loss: 97.0164 - val_loss: 122.3281
# Epoch 20/50
# 101/101 [==============================] - 127s 1s/step - loss: 95.5191 - val_loss: 125.7149
# Epoch 21/50
# 101/101 [==============================] - 128s 1s/step - loss: 93.7156 - val_loss: 106.5344
# Epoch 22/50
# 101/101 [==============================] - 131s 1s/step - loss: 91.9113 - val_loss: 100.3732
# Epoch 23/50
# 101/101 [==============================] - 127s 1s/step - loss: 90.5423 - val_loss: 98.2933
# Epoch 24/50
# 101/101 [==============================] - 128s 1s/step - loss: 89.0707 - val_loss: 104.0945
# Epoch 25/50
# 101/101 [==============================] - 128s 1s/step - loss: 87.8008 - val_loss: 108.3891
# Epoch 26/50
# 101/101 [==============================] - 129s 1s/step - loss: 86.4734 - val_loss: 114.1915
# Epoch 27/50
# 101/101 [==============================] - 128s 1s/step - loss: 85.0901 - val_loss: 101.5576
# Epoch 28/50
# 101/101 [==============================] - 128s 1s/step - loss: 83.5047 - val_loss: 108.3802
# Epoch 29/50
# 101/101 [==============================] - 128s 1s/step - loss: 82.6577 - val_loss: 106.6975
# Epoch 30/50
# 101/101 [==============================] - 127s 1s/step - loss: 81.1828 - val_loss: 123.7572
# Epoch 31/50
# 101/101 [==============================] - 127s 1s/step - loss: 80.2016 - val_loss: 112.1097
# Epoch 32/50
# 101/101 [==============================] - 127s 1s/step - loss: 79.4736 - val_loss: 106.1283
# Epoch 33/50
# 101/101 [==============================] - 126s 1s/step - loss: 78.4714 - val_loss: 103.9420
# Epoch 34/50
# 101/101 [==============================] - 127s 1s/step - loss: 77.4225 - val_loss: 106.6944
# Epoch 35/50
# 101/101 [==============================] - 127s 1s/step - loss: 76.4031 - val_loss: 106.3029
# Epoch 36/50
# 101/101 [==============================] - 131s 1s/step - loss: 75.1968 - val_loss: 113.3756
# Epoch 37/50
# 101/101 [==============================] - 128s 1s/step - loss: 74.8985 - val_loss: 119.1145
# Epoch 38/50
# 101/101 [==============================] - 128s 1s/step - loss: 74.1869 - val_loss: 124.2121
# Epoch 39/50
# 101/101 [==============================] - 126s 1s/step - loss: 72.9945 - val_loss: 117.6255
# Epoch 40/50
# 101/101 [==============================] - 127s 1s/step - loss: 72.3357 - val_loss: 101.4187
# Epoch 41/50
# 101/101 [==============================] - 127s 1s/step - loss: 71.4383 - val_loss: 137.8262
# Epoch 42/50
# 101/101 [==============================] - 127s 1s/step - loss: 70.8172 - val_loss: 115.1006
# Epoch 43/50
# 101/101 [==============================] - 128s 1s/step - loss: 69.8801 - val_loss: 71.7170
# Epoch 44/50
# 101/101 [==============================] - 128s 1s/step - loss: 69.3311 - val_loss: 125.3234
# Epoch 45/50
# 101/101 [==============================] - 129s 1s/step - loss: 68.4605 - val_loss: 112.0685
# Epoch 46/50
# 101/101 [==============================] - 127s 1s/step - loss: 67.6645 - val_loss: 106.7710
# Epoch 47/50
# 101/101 [==============================] - 128s 1s/step - loss: 67.3782 - val_loss: 111.9415
# Epoch 48/50
# 101/101 [==============================] - 128s 1s/step - loss: 66.7665 - val_loss: 119.1735
# Epoch 49/50
# 101/101 [==============================] - 127s 1s/step - loss: 66.0241 - val_loss: 156.5747
# Epoch 50/50
# 101/101 [==============================] - 131s 1s/step - loss: 65.2267 - val_loss: 100.2959

# %% [markdown]
# Please execute the code cell below to train the neural network you specified in `input_to_softmax`.  After the model has finished training, the model is [saved](https://keras.io/getting-started/faq/#how-can-i-save-a-keras-model) in the HDF5 file `model_end.h5`.  The loss history is [saved](https://wiki.python.org/moin/UsingPickle) in `model_end.pickle`.  You are welcome to tweak any of the optional parameters while calling the `train_model` function, but this is not required.

# %%
plotModels("results/final/")

# %% [markdown]
# __Question 2:__ Describe your final model architecture and your reasoning at each step.
#
# __Answer:__
#
# Final_Model = CNN 3xBidirectional(RNN(Dropout = 0.3)) Time Distributed
#
# The final model consists of one CNN layer, then 3 bidirectional rnn layers, and finally a Time Distributed layer
#
# Experiments were made teting out dropdown, dilated convolutions, maxpolling and several RNN layers.
#
# The experiments showed that several rnn layers all with dropout could be a vald approach. it took more pochs to train, and the final model is trained for 50 instead of 20 epochs.

# %% [markdown]
# <a id='step3'></a>
# ## STEP 3: Obtain Predictions
#
# We have written a function for you to decode the predictions of your acoustic model.  To use the function, please execute the code cell below.

# %%
import numpy as np
from data_generator import AudioGenerator
from keras import backend as K
from utils import int_sequence_to_text
from IPython.display import Audio

def get_predictions(index, partition, input_to_softmax, model_path):
    """ Print a model's decoded predictions
    Params:
        index (int): The example you would like to visualize
        partition (str): One of 'train' or 'validation'
        input_to_softmax (Model): The acoustic model
        model_path (str): Path to saved acoustic model's weights
    """
    # load the train and test data
    data_gen = AudioGenerator()
    data_gen.load_train_data()
    data_gen.load_validation_data()
    
    # obtain the true transcription and the audio features 
    if partition == 'validation':
        transcr = data_gen.valid_texts[index]
        audio_path = data_gen.valid_audio_paths[index]
        data_point = data_gen.normalize(data_gen.featurize(audio_path))
    elif partition == 'train':
        transcr = data_gen.train_texts[index]
        audio_path = data_gen.train_audio_paths[index]
        data_point = data_gen.normalize(data_gen.featurize(audio_path))
    else:
        raise Exception('Invalid partition!  Must be "train" or "validation"')
        
    # obtain and decode the acoustic model's predictions
    input_to_softmax.load_weights(model_path)
    prediction = input_to_softmax.predict(np.expand_dims(data_point, axis=0))
    output_length = [input_to_softmax.output_length(data_point.shape[0])] 
    pred_ints = (K.eval(K.ctc_decode(
                prediction, output_length)[0][0])+1).flatten().tolist()
    
    # play the audio file, and display the true and predicted transcriptions
    print('-'*80)
    Audio(audio_path)
    print('True transcription:\n' + '\n' + transcr)
    print('-'*80)
    print('Predicted transcription:\n' + '\n' + ''.join(int_sequence_to_text(pred_ints)))
    print('-'*80)

# %% [markdown]
# Use the code cell below to obtain the transcription predicted by your final model for the first example in the training dataset.

# %%
get_predictions(index=0, 
                partition='train',
                input_to_softmax=final_model(input_dim=161, # change to 13 if you would like to use MFCC features
                            filters=200,
                            kernel_size=11, 
                            conv_stride=2,
                            conv_border_mode='valid',
                            units=200,
                            rnn_layers=3,
                            dropout = 0.3,
                            recurrent_dropout = 0,
                            dilation_rate=1,
                            pool_size = 1), 
                model_path='results/model_end.h5')
# Out:
# Model: "model_49"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# the_input (InputLayer)       (None, None, 161)         0
# _________________________________________________________________
# conv1d (Conv1D)              (None, None, 200)         354400
# _________________________________________________________________
# max_pooling1d_19 (MaxPooling (None, None, 200)         0
# _________________________________________________________________
# bidirectional_28 (Bidirectio (None, None, 400)         481200
# _________________________________________________________________
# bidirectional_29 (Bidirectio (None, None, 400)         721200
# _________________________________________________________________
# bidirectional_30 (Bidirectio (None, None, 400)         721200
# _________________________________________________________________
# batch_normalization_33 (Batc (None, None, 400)         1600
# _________________________________________________________________
# time_distributed_24 (TimeDis (None, None, 29)          11629
# _________________________________________________________________
# softmax (Activation)         (None, None, 29)          0
# =================================================================
# Total params: 2,291,229
# Trainable params: 2,290,429
# Non-trainable params: 800
# _________________________________________________________________
# None
# --------------------------------------------------------------------------------
# True transcription:
#
# her father is a most remarkable person to say the least
# --------------------------------------------------------------------------------
# Predicted transcription:
#
# erfather as amoferam markablaperson to sa the lest
# --------------------------------------------------------------------------------

# %% [markdown]
# Use the next code cell to visualize the model's prediction for the first example in the validation dataset.

# %%
get_predictions(index=0, 
                partition='validation',
                input_to_softmax=final_model(input_dim=161, # change to 13 if you would like to use MFCC features
                            filters=200,
                            kernel_size=11, 
                            conv_stride=2,
                            conv_border_mode='valid',
                            units=200,
                            rnn_layers=3,
                            dropout = 0.3,
                            recurrent_dropout = 0,
                            dilation_rate=1,
                            pool_size = 1), 
                model_path='results/model_end.h5')
# Out:
# Model: "model_50"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# the_input (InputLayer)       (None, None, 161)         0
# _________________________________________________________________
# conv1d (Conv1D)              (None, None, 200)         354400
# _________________________________________________________________
# max_pooling1d_20 (MaxPooling (None, None, 200)         0
# _________________________________________________________________
# bidirectional_31 (Bidirectio (None, None, 400)         481200
# _________________________________________________________________
# bidirectional_32 (Bidirectio (None, None, 400)         721200
# _________________________________________________________________
# bidirectional_33 (Bidirectio (None, None, 400)         721200
# _________________________________________________________________
# batch_normalization_36 (Batc (None, None, 400)         1600
# _________________________________________________________________
# time_distributed_25 (TimeDis (None, None, 29)          11629
# _________________________________________________________________
# softmax (Activation)         (None, None, 29)          0
# =================================================================
# Total params: 2,291,229
# Trainable params: 2,290,429
# Non-trainable params: 800
# _________________________________________________________________
# None
# --------------------------------------------------------------------------------
# True transcription:
#
# the bogus legislature numbered thirty six members
# --------------------------------------------------------------------------------
# Predicted transcription:
#
# the biltis logeslature neverthirty sits lemvers
# --------------------------------------------------------------------------------

# %% [markdown]
# One standard way to improve the results of the decoder is to incorporate a language model.  We won't pursue this in the notebook, but you are welcome to do so as an _optional extension_.
#
# If you are interested in creating models that provide improved transcriptions, you are encouraged to download [more data](http://www.openslr.org/12/) and train bigger, deeper models.  But beware - the model will likely take a long while to train.  For instance, training this [state-of-the-art](https://arxiv.org/pdf/1512.02595v1.pdf) model would take 3-6 weeks on a single GPU!
